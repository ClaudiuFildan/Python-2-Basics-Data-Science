# %%
# Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3=pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',s=50,c='red',figsize=(12,3))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df3['a'].plot.hist(bins=20,alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
# Create a boxplot comparing the a and b columns.

# %%
df3[['a','b']].plot.box()
# Out:
# <Axes: >

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Figure out how to increase the linewidth and make the linestyle dashed
# You wouls usually not dash a kde plot line

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
df3['d'].plot.density(lw=5,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
# Create an area plot of all the columns for just the rows up to  30. (hint use .ix)

# %%
df3.ix[0:30].plot.area(alpha=0.4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32180\3731730886.py in ?()
# ----> 1 df3.ix[0:30].plot.area(alpha=0.4)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
# Bonus Section
# How to display the legend outsideof the figure below

# %%
f=plt.figure
df3.ix[0:30].plot.area(alpha=0.4)
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32180\805496065.py in ?()
#       1 f=plt.figure
# ----> 2 df3.ix[0:30].plot.area(alpha=0.4)
#       3 plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))
#       4 plt.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
