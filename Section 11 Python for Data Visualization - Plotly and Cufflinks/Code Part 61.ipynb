# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.9.0

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cf.go_offline()
#
# NameError: name 'cf' is not defined

# %%
# DATA

# %%
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.994922 -0.008008 -2.394953 -0.786025
# 1 -1.199259 -0.046246  0.808851  0.153274
# 2 -1.197982 -1.216936 -1.234327 -1.069100
# 3  0.316389 -0.818427  0.699595 -1.319373
# 4 -1.396736  0.615565 -0.821288 -1.497198

# %%
df2=pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='scatter',x='A',y='B',mode='markers',size=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.plot(kind='scatter',x='A',y='B',mode='markers',size=20)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     918 if kind in self._dataframe_kinds:
#     919     if isinstance(data, ABCDataFrame):
# --> 920         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921     else:
#     922         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df2 #.iplot(kind='bar',x=)
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df2.plot(kind='bar',x='Category',y='Values')
# Out:
# <Axes: xlabel='Category'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.count().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})

# %%
df3.plot(kind='surface')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df3.plot(kind='surface')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:908, in PlotAccessor.__call__(self, *args, **kwargs)
#     905     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     907 if kind not in self._all_kinds:
# --> 908     raise ValueError(f"{kind} is not a valid plot kind")
#     910 # The original data structured can be transformed before passed to the
#     911 # backend. For example, for DataFrame is common to set the index as the
#     912 # `x` parameter, and return a Series with the parameter `y` as values.
#     913 data = self._parent.copy()
#
# ValueError: surface is not a valid plot kind

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.plot(kind='surface',colorscale='rdylbu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df3.plot(kind='surface',colorscale='rdylbu')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:908, in PlotAccessor.__call__(self, *args, **kwargs)
#     905     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     907 if kind not in self._all_kinds:
# --> 908     raise ValueError(f"{kind} is not a valid plot kind")
#     910 # The original data structured can be transformed before passed to the
#     911 # backend. For example, for DataFrame is common to set the index as the
#     912 # `x` parameter, and return a Series with the parameter `y` as values.
#     913 data = self._parent.copy()
#
# ValueError: surface is not a valid plot kind

# %%
df['A'].plot(kind='hist',bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['A','B']].plot(kind='spread')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df[['A','B']].plot(kind='spread')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:908, in PlotAccessor.__call__(self, *args, **kwargs)
#     905     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     907 if kind not in self._all_kinds:
# --> 908     raise ValueError(f"{kind} is not a valid plot kind")
#     910 # The original data structured can be transformed before passed to the
#     911 # backend. For example, for DataFrame is common to set the index as the
#     912 # `x` parameter, and return a Series with the parameter `y` as values.
#     913 data = self._parent.copy()
#
# ValueError: spread is not a valid plot kind

# %%
df.plot(kind='Bubble',x='A',y='B',size='C')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.plot(kind='Bubble',x='A',y='B',size='C')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:908, in PlotAccessor.__call__(self, *args, **kwargs)
#     905     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     907 if kind not in self._all_kinds:
# --> 908     raise ValueError(f"{kind} is not a valid plot kind")
#     910 # The original data structured can be transformed before passed to the
#     911 # backend. For example, for DataFrame is common to set the index as the
#     912 # `x` parameter, and return a Series with the parameter `y` as values.
#     913 data = self._parent.copy()
#
# ValueError: Bubble is not a valid plot kind

# %%
df.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5792\3454576310.py in ?()
# ----> 1 df.scatter_matrix()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'scatter_matrix'
